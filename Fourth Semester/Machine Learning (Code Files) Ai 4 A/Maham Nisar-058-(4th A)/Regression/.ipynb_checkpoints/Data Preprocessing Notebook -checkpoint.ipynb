# %% [markdown]
# # Data Description

# %% [markdown]
# This dataset is having data of customers who buys clothes online. The store offers in-store style and clothing advice sessions. Customers come in to the store, have sessions/meetings with a personal stylist, then they can go home and order either on a mobile app or website for the clothes they want.
#
# The company is trying to decide whether to focus their efforts on their mobile app experience or their website.

# %% [markdown]
# # Data Preprocessing Steps

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
color = sns.color_palette()

import numpy as np
import pandas as pd

# %% [markdown]
# # 1: Reading Data

# %%
data = pd.read_csv('Ecommerce Customers')

data.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
data.head(2)
# Out:
#                        Email                                         Address  \
# 0  mstephenson@fernandez.com    835 Frank Tunnel\nWrightmouth, MI 82180-9605
# 1          hduke@hotmail.com  4547 Archer Common\nDiazchester, CA 06566-8576
#
#       Avatar  Avg. Session Length  Time on App  Time on Website  \
# 0     Violet            34.497268    12.655651        39.577668
# 1  DarkGreen            31.926272    11.109461        37.268959
#
#    Length of Membership  Yearly Amount Spent
# 0              4.082621           587.951054
# 1              2.664034           392.204933

# %%
data.head(30)
# Out:
#                               Email  \
# 0         mstephenson@fernandez.com
# 1                 hduke@hotmail.com
# 2                  pallen@yahoo.com
# 3           riverarebecca@gmail.com
# 4     mstephens@davidson-herman.com
# 5            alvareznancy@lucas.biz
# 6             katherine20@yahoo.com
# 7                awatkins@yahoo.com
# 8       vchurch@walter-martinez.com
# 9                  bonnie69@lin.biz
# 10            andrew06@peterson.com
# 11           ryanwerner@freeman.biz
# 12                knelson@gmail.com
# 13            wrightpeter@yahoo.com
# 14            taylormason@gmail.com
# 15              jstark@anderson.com
# 16              wjennings@gmail.com
# 17         rebecca45@hale-bauer.biz
# 18          alejandro75@hotmail.com
# 19           samuel46@love-west.net
# 20                megan33@gmail.com
# 21                agolden@yahoo.com
# 22            vstafford@hotmail.com
# 23  denise22@hernandez-townsend.com
# 24           youngbarbara@yahoo.com
# ...

# %%
data.tail()
# Out:
#                             Email  \
# 495  lewisjessica@craig-evans.com
# 496           katrina56@gmail.com
# 497            dale88@hotmail.com
# 498           cwilson@hotmail.com
# 499     hannahwilson@davidson.com
#
#                                                Address         Avatar  \
# 495  4483 Jones Motorway Suite 872\nLake Jamiefurt,...            Tan
# 496  172 Owen Divide Suite 497\nWest Richard, CA 19320  PaleVioletRed
# 497  0787 Andrews Ranch Apt. 633\nSouth Chadburgh, ...       Cornsilk
# 498  680 Jennifer Lodge Apt. 808\nBrendachester, TX...           Teal
# 499  49791 Rachel Heights Apt. 898\nEast Drewboroug...    DarkMagenta
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 495            33.237660    13.566160        36.417985              3.746573
# 496            34.702529    11.695736        37.190268              3.576526
# 497            32.646777    11.499409        38.332576              4.958264
# ...

# %%
data.shape
# Out:
# (500, 8)

# %%
data.tail(20)
# Out:
#                              Email  \
# 480      christopher44@hotmail.com
# 481     autumn88@mendoza-mills.com
# 482              dhudson@ramos.net
# 483             egomez@hotmail.com
# 484  kimberlyruiz@smith-gordon.com
# 485        mooremichelle@logan.com
# 486              aaron22@gmail.com
# 487     michelleshepherd@price.com
# 488              zscott@wright.com
# 489            tracy79@wheeler.net
# 490            brian28@sanchez.org
# 491     leonardhancock@hotmail.com
# 492     davidsonkathleen@gmail.com
# 493            nathan84@lowery.net
# 494          kellydeborah@chan.biz
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address          Avatar  \
# 480         549 Anna Avenue\nPort Laura, CA 76209-9339      WhiteSmoke
# ...

# %%
data.sample()
# Out:
#                   Email                                          Address  \
# 195  mary84@edwards.com  19123 Craig Isle Apt. 719\nMillsmouth, SC 94194
#
#            Avatar  Avg. Session Length  Time on App  Time on Website  \
# 195  LightSkyBlue            31.820998    10.771074         37.27864
#
#      Length of Membership  Yearly Amount Spent
# 195              3.519032           424.675281

# %%
data.sample(30)
# Out:
#                             Email  \
# 314         williammoore@rose.com
# 374             aaron89@gmail.com
# 422             robin80@yahoo.com
# 130    lewisgabrielle@hotmail.com
# 219         longphillip@yahoo.com
# 137   ashleychristopher@gmail.com
# 290      phillipscarrie@gmail.com
# 471            prussell@lopez.com
# 338     christianwade@butler.info
# 111              tknapp@yahoo.com
# 255            pkline@hotmail.com
# 79    kimberlyfrederick@gmail.com
# 367         carolfarley@gmail.com
# 455              lmunoz@yahoo.com
# 278           kenneth27@smith.com
# 25        william25@mcconnell.com
# 477           ncummings@yahoo.com
# 468     philliproberson@yahoo.com
# 464         susanibarra@yahoo.com
# 386           michael86@yahoo.com
# 420         edwardbrown@yahoo.com
# 233  patriciajackson@jenkins.info
# 114            hailey18@yahoo.com
# 143           kaitlyn78@chang.com
# 385              thardy@perry.com
# 478             hking@hotmail.com
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
data.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %% [markdown]
# # 2: Data Cleaning

# %% [markdown]
# Handling Missing Values
# -
# - Imputation: Filling missing values with mean.

# %%
data.isnull().sum()
# Out:
# Email                   0
# Address                 0
# Avatar                  0
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# dtype: int64

# %%
import pandas as pd
import numpy as np

numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])

numeric_cols.fillna(numeric_cols.mean(), inplace=True)  

data = pd.concat([numeric_cols, non_numeric_cols], axis=1)

missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# Email                   0
# Address                 0
# Avatar                  0
# dtype: int64

# %%
import pandas as pd
import numpy as np

numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])

numeric_cols = numeric_cols.fillna(numeric_cols.mean()) 

for col in non_numeric_cols.columns:
    non_numeric_cols[col] = non_numeric_cols[col].fillna(non_numeric_cols[col].mode()[0])

data = pd.concat([numeric_cols, non_numeric_cols], axis=1)


missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# Email                   0
# Address                 0
# Avatar                  0
# dtype: int64

# %%
data.shape
# Out:
# (500, 8)

# %% [markdown]
# Removal: Deleting rows with missing values.
# -

# %%
data.isnull().sum()
# Out:
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# Email                   0
# Address                 0
# Avatar                  0
# dtype: int64

# %%
data.shape
# Out:
# (500, 8)

# %%
data.dropna(inplace=True)

missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Avg. Session Length     0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# Email                   0
# Address                 0
# Avatar                  0
# dtype: int64

# %%
data.shape
# Out:
# (500, 8)

# %% [markdown]
# Removing Duplicates
# -

# %%
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (500, 8)

# %% [markdown]
# # 3: Outlier Detection and Removal

# %%
data.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
0.25-1.5*0.5
# Out:
# -0.5

# %%
0.75 + 1.5 * 0.5
# Out:
# 1.5

# %%
numeric_cols = data.select_dtypes(include=[np.number])

Q1 = numeric_cols.quantile(0.25)
Q3 = numeric_cols.quantile(0.75)
IQR = Q3 - Q1

data_cleaned = data[~((numeric_cols < (Q1 - 1.5 * IQR)) | (numeric_cols > (Q3 + 1.5 * IQR))).any(axis=1)]

plt.figure(figsize=(20, 6))

plt.subplot(1, 2, 1)
numeric_cols.boxplot()
plt.title("Before Outlier Removal")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 6))

plt.subplot(1, 2, 2)
data_cleaned.select_dtypes(include=[np.number]).boxplot()
plt.title("After Outlier Removal")

plt.tight_layout()
plt.show()

# %%
data_cleaned.shape
# Out:
# (476, 8)

# %%
data_cleaned.shape
# Out:
# (476, 8)

# %% [markdown]
# # 4. Data Transformation

# %%
numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])

scaler = MinMaxScaler()
scaled_numeric_data = scaler.fit_transform(numeric_cols)

scaled_numeric_df = pd.DataFrame(scaled_numeric_data, columns=numeric_cols.columns)

scaled_data = pd.concat([scaled_numeric_df, non_numeric_cols.reset_index(drop=True)], axis=1)

print(scaled_data.shape)
print()
print('*' * 60)
scaled_data.head()
# Out:
# (500, 8)
#
# ************************************************************
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0             0.751425     0.626620         0.929816              0.573101
# 1             0.362306     0.393016         0.550801              0.359869
# 2             0.524953     0.426378         0.524803              0.576396
# 3             0.722409     0.787050         0.460890              0.428434
# 4             0.574861     0.647702         0.594748              0.627768
#
#    Yearly Amount Spent                          Email  \
# 0             0.651040      mstephenson@fernandez.com
# 1             0.266355              hduke@hotmail.com
# 2             0.453725               pallen@yahoo.com
# 3             0.639055        riverarebecca@gmail.com
# 4             0.673552  mstephens@davidson-herman.com
#
#                                              Address            Avatar
# ...

# %% [markdown]
# Standardization
# -
# Definition:
# Standardization rescales the data so that it has a mean of 0 and a standard deviation of 1.

# %%
numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])

scaler = StandardScaler()
scaled_numeric_data = scaler.fit_transform(numeric_cols)

scaled_numeric_df = pd.DataFrame(scaled_numeric_data, columns=numeric_cols.columns)

scaled_data = pd.concat([scaled_numeric_df, non_numeric_cols.reset_index(drop=True)], axis=1)

print(scaled_data.shape)
print()
print('*' * 60)
scaled_data.head()
# Out:
# (500, 8)
#
# ************************************************************
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0             1.456351     0.607280         2.493589              0.550107
# 1            -1.136502    -0.949464         0.206556             -0.870927
# 2            -0.052723    -0.727139         0.049681              0.572067
# 3             1.263010     1.676390        -0.335978             -0.413996
# 4             0.279838     0.747770         0.471737              0.914422
#
#    Yearly Amount Spent                          Email  \
# 0             1.118654      mstephenson@fernandez.com
# 1            -1.351783              hduke@hotmail.com
# 2            -0.148501               pallen@yahoo.com
# 3             1.041684        riverarebecca@gmail.com
# 4             1.263224  mstephens@davidson-herman.com
#
#                                              Address            Avatar
# ...

# %% [markdown]
# # 5: One-Hot Encoding

# %%
data.head(2)
# Out:
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
#
#    Yearly Amount Spent                      Email  \
# 0           587.951054  mstephenson@fernandez.com
# 1           392.204933          hduke@hotmail.com
#
#                                           Address     Avatar
# 0    835 Frank Tunnel\nWrightmouth, MI 82180-9605     Violet
# 1  4547 Archer Common\nDiazchester, CA 06566-8576  DarkGreen

# %%
data.columns = data.columns.str.strip()

# %%
data["Avg. Session Length"].unique()
# Out:
# array([34.49726773, 31.92627203, 33.00091476, 34.30555663, 33.33067252,
#        33.87103788, 32.0215955 , 32.73914294, 33.9877729 , 31.93654862,
#        33.99257277, 33.87936082, 29.53242897, 33.19033404, 32.38797585,
#        30.73772037, 32.1253869 , 32.33889932, 32.18781205, 32.61785606,
#        32.91278511, 33.50308726, 31.53160448, 32.90325097, 34.507551  ,
#        33.02933195, 33.54123131, 32.33598964, 33.11020506, 33.10543794,
#        33.24190043, 33.4610563 , 32.17550124, 32.72836   , 32.82030995,
#        33.61603789, 31.72165236, 32.86532717, 32.74936818, 32.56723048,
#        32.07054622, 33.01954799, 33.79203908, 32.89398062, 32.04448613,
#        34.55576799, 34.56455771, 32.7267846 , 33.11721873, 31.66104982,
#        33.25633547, 33.90022441, 34.18777483, 33.76206924, 34.39016366,
#        33.9252966 , 32.6882293 , 34.30187022, 32.84393022, 33.75499473,
#        33.87978429, 33.07653561, 32.22729914, 32.78977262, 32.77260993,
# ...

# %%
print(data.columns)
# Out:
# Index(['Avg. Session Length', 'Time on App', 'Time on Website',
#        'Length of Membership', 'Yearly Amount Spent', 'Email', 'Address',
#        'Avatar'],
#       dtype='object')

# %%
cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']

data1 = pd.get_dummies(cat_features)
data1
# Out:
#    Address  Avatar  Email
# 0    False   False   True
# 1     True   False  False
# 2    False    True  False

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Address  3 non-null      bool
#  1   Avatar   3 non-null      bool
#  2   Email    3 non-null      bool
# dtypes: bool(3)
# memory usage: 141.0 bytes

# %%
cat_features
# Out:
# ['Email', 'Address', 'Avatar']

# %%
cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']

data1 = pd.get_dummies(data, columns=cat_features)

scaled_data = pd.concat([data, data1], axis=1)

print(scaled_data.shape)
print()
print('*' * 70)

scaled_data.head()
# Out:
# (500, 1151)
#
# **********************************************************************
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent                          Email  \
# 0           587.951054      mstephenson@fernandez.com
# 1           392.204933              hduke@hotmail.com
# 2           487.547505               pallen@yahoo.com
# 3           581.852344        riverarebecca@gmail.com
# 4           599.406092  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# ...

# %%
data.columns
# Out:
# Index(['Avg. Session Length', 'Time on App', 'Time on Website',
#        'Length of Membership', 'Yearly Amount Spent', 'Email', 'Address',
#        'Avatar'],
#       dtype='object')

# %%
scaled_data.columns
# Out:
# Index(['Avg. Session Length', 'Time on App', 'Time on Website',
#        'Length of Membership', 'Yearly Amount Spent', 'Email', 'Address',
#        'Avatar', 'Avg. Session Length', 'Time on App',
#        ...
#        'Avatar_Teal', 'Avatar_Thistle', 'Avatar_Tomato', 'Avatar_Turquoise',
#        'Avatar_Violet', 'Avatar_Wheat', 'Avatar_White', 'Avatar_WhiteSmoke',
#        'Avatar_Yellow', 'Avatar_YellowGreen'],
#       dtype='object', length=1151)

# %%
data1.head()
# Out:
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent  Email_aaron04@yahoo.com  Email_aaron11@luna.com  \
# 0           587.951054                    False                   False
# 1           392.204933                    False                   False
# 2           487.547505                    False                   False
# 3           581.852344                    False                   False
# 4           599.406092                    False                   False
#
#    Email_aaron22@gmail.com  Email_aaron89@gmail.com  \
# ...

# %% [markdown]
# # 6: Data Reduction

# %%
scaled_data.shape
# Out:
# (500, 1151)

# %%
cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']

data = pd.get_dummies(data, columns=cat_features)

scaler = StandardScaler()
data[numeric_features] = scaler.fit_transform(data[numeric_features].values)

pca = PCA(n_components=15)
data_pca = pca.fit_transform(data)

print(data_pca.shape)
print(data_pca[:5]) 

plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.scatter(data[numeric_features[0]], data[numeric_features[1]], alpha=0.5)
plt.title('Original Data')
plt.xlabel(numeric_features[0])
plt.ylabel(numeric_features[1])

pca = PCA(n_components=15) 
data_pca = pca.fit_transform(data)

plt.subplot(1, 2, 2)
plt.scatter(data_pca[:, 0], data_pca[:, 1], alpha=0.5)
plt.title('PCA Transformed Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')

plt.tight_layout()
plt.show()
# Out:
# (500, 15)
# [[ 1.66056818e+00 -1.32845514e+00 -2.20566271e+00 -9.56732281e-01
#    2.33776954e-02 -4.55128938e-04 -6.39931929e-03 -5.60504990e-03
#   -8.63122507e-03 -2.00556280e-02  1.08740081e-03  6.58838845e-03
#    8.81165668e-03  1.81502608e-02 -8.23927801e-03]
#  [-2.07011399e+00 -1.66289972e-01  4.56659621e-01 -5.51718812e-01
#   -1.35243430e-01 -1.48410474e-02 -4.38954926e-02  3.78975035e-02
#   -1.35610644e-01  1.16362969e-01  6.19175226e-04  3.29130336e-02
#   -1.16706898e-01 -7.29077854e-02 -1.73443363e-01]
#  [-4.38245045e-02  5.08114661e-01  1.09692293e-01 -7.60121027e-01
#    6.82412508e-02 -2.08444376e-02 -1.57711283e-02 -2.44137656e-02
#   -3.85209157e-02 -2.50957296e-01  1.07549696e-01  3.35767814e-02
#    1.51108183e-01 -7.21695423e-02  1.58312435e-02]
#  [ 1.39836554e+00 -3.99390243e-01 -8.05792348e-01  1.72936212e+00
#   -3.68683101e-02  1.40287160e-03 -2.72768525e-02 -4.12026084e-02
#   -8.52664530e-02 -9.05521089e-02  5.55468663e-02 -3.28941048e-01
# ...

# %%
type(data_pca)
# Out:
# numpy.ndarray

# %%
data_pca.ndim
# Out:
# 2

# %%
data_pca.shape
# Out:
# (500, 15)

# %% [markdown]
# # 7: Handling Imbalanced Data
#
# - Resampling Techniques
# - Oversampling

# %%
cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O' and feature != target_col]

data = pd.get_dummies(data, columns=cat_features)

scaler = StandardScaler()
data[numeric_features] = scaler.fit_transform(data[numeric_features].values)

threshold = data[target_col].mean()
data[target_col] = (data[target_col] > threshold).astype(int)

X = data.drop(columns=[target_col])
y = data[target_col]

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

data_resampled = pd.concat(
    [pd.DataFrame(X_resampled, columns=X.columns), pd.DataFrame(y_resampled, columns=[target_col])],
    axis=1
)

print("Resampled data shape:", data_resampled.shape)
data_resampled.head()
# Out:
# Resampled data shape: (502, 1143)
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0             1.456351     0.607280         2.493589              0.550107
# 1            -1.136502    -0.949464         0.206556             -0.870927
# 2            -0.052723    -0.727139         0.049681              0.572067
# 3             1.263010     1.676390        -0.335978             -0.413996
# 4             0.279838     0.747770         0.471737              0.914422
#
#    Email_aaron04@yahoo.com  Email_aaron11@luna.com  Email_aaron22@gmail.com  \
# 0                -0.044766               -0.044766                -0.044766
# 1                -0.044766               -0.044766                -0.044766
# 2                -0.044766               -0.044766                -0.044766
# 3                -0.044766               -0.044766                -0.044766
# 4                -0.044766               -0.044766                -0.044766
#
# ...

# %%
data_resampled['Yearly Amount Spent'].value_counts(normalize=True)
# Out:
# Yearly Amount Spent
# 1    0.5
# 0    0.5
# Name: proportion, dtype: float64

# %%
data_resampled.shape
# Out:
# (502, 1143)

# %% [markdown]
# Undersampling
# -

# %%
 data.fillna(data.mean(numeric_only=True), inplace=True)

median_spent = data['Yearly Amount Spent'].median()
data['HighSpender'] = (data['Yearly Amount Spent'] > median_spent).astype(int)

cat_features = [col for col in data.columns if data[col].dtype == 'O']
numeric_features = [col for col in data.columns if data[col].dtype != 'O' and col != 'HighSpender']

data = pd.get_dummies(data, columns=cat_features)

scaler = StandardScaler()
data[numeric_features] = scaler.fit_transform(data[numeric_features])

X = data.drop(columns=['HighSpender'])
y = data['HighSpender']

rus = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = rus.fit_resample(X, y)

data_resampled = pd.concat([
    pd.DataFrame(X_resampled, columns=X.columns),
    pd.DataFrame(y_resampled, columns=['HighSpender'])
], axis=1)

print(data_resampled['HighSpender'].value_counts(normalize=True))

data_resampled.head()
# Out:
# HighSpender
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 322             0.213236    -1.329369        -0.906066              0.554059
# 15             -2.335158     0.588105        -0.838733             -0.175918
# 335            -0.927147    -0.442839         2.167812             -0.184534
# 123            -1.709124     0.762565        -0.505982              0.104420
# 234             1.153591     0.987774         0.016196             -0.901594
#
#      Yearly Amount Spent  Email_aaron04@yahoo.com  Email_aaron11@luna.com  \
# 322            -0.996008                -0.044766               -0.044766
# 15             -0.996008                -0.044766               -0.044766
# 335            -0.996008                -0.044766               -0.044766
# 123            -0.996008                -0.044766               -0.044766
# ...

# %%
data_resampled['Yearly Amount Spent'].value_counts(normalize=True)
# Out:
# Yearly Amount Spent
# -1.351783    0.002
#  0.030734    0.002
#  3.359664    0.002
#  2.544355    0.002
#  1.483396    0.002
#              ...
# -0.947950    0.002
# -0.722526    0.002
# -0.684692    0.002
# -0.971097    0.002
#  0.070125    0.002
# Name: proportion, Length: 500, dtype: float64

# %%
data_resampled.shape
# Out:
# (500, 1144)

# %% [markdown]
# # Target Encoder

# %%
address_mean = df.groupby('Address')['Yearly Amount Spent'].mean()

df['Address_encoded'] = df['Address'].map(address_mean)

df[['Address', 'Address_encoded']].head()
# Out:
#                                              Address  Address_encoded
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605       587.951054
# 1     4547 Archer Common\nDiazchester, CA 06566-8576       392.204933
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...       487.547505
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       581.852344
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...       599.406092

# %% [markdown]
# # 8: Splitting Data

# %%
X = data.drop('Yearly Amount Spent', axis=1)
y = data['Yearly Amount Spent']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((350, 1143), (150, 1143), (350,), (150,))
